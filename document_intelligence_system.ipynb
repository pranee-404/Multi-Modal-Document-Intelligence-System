# %% [markdown]
# <a href="https://colab.research.google.com/github/pranee-404/Multi-Modal-Document-Intelligence-System/blob/main/document_intelligence_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello')
# Out:
# hello
